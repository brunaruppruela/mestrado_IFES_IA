# %% [markdown]
# # Importacoes e instalacoes

# %%
# !pip install "stable-baselines3[extra]>=2.0.0a4"

# %%
import gymnasium as gym
import numpy as np
import torch as th
import matplotlib.pyplot as plt

from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # Inicialização do ambiente:

# %%
env = gym.make("MountainCar-v0", render_mode="rgb_array") #criacao do ambiente usando a biblioteca Gym

# %% [markdown]
# Salvando os logs:

# %%
tensorboard_log = "mountaincar/"

# %% [markdown]
# # Configurando o modelo com SB3

# %%
# The learning agent and hyperparameters
dqn_model = DQN(
    "MlpPolicy",                # Política utilizada pelo agente, uma rede MLP (Multi-Layer Perceptron)
    env,                        # O ambiente no qual o agente vai operar
    verbose=1,                  # Nível de verbosidade (1 para exibir mensagens de treinamento)
    train_freq=16,              # Frequência com que o agente realiza o treinamento (a cada 16 passos)
    gradient_steps=8,           # Número de passos de gradiente realizados após cada atualização de rede
    gamma=0.99,                 # Fator de desconto (gamma), que determina a importância de recompensas futuras
    exploration_fraction=0.2,   # Fração do treinamento durante a qual a exploração é realizada
    exploration_final_eps=0.07, # Valor final de epsilon após a fase de exploração (para a política epsilon-greedy)
    target_update_interval=600, # Intervalo de atualização da rede alvo (em passos de tempo)
    learning_starts=1000,       # Número de passos antes do início do aprendizado (pré-treinamento)
    buffer_size=10000,          # Tamanho do buffer de replay (memória de experiência)
    batch_size=128,             # Tamanho do lote (batch) para treinamento da rede neural
    learning_rate=4e-3,         # Taxa de aprendizado (learning rate) da rede neural
    policy_kwargs=dict(net_arch=[256, 256]),  # Arquitetura da rede (duas camadas densas de 256 neurônios cada)
    tensorboard_log=tensorboard_log,          # Diretório para armazenar logs do TensorBoard
    seed=2,                     # Semente para geração de números aleatórios (para reprodutibilidade)
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# # Avaliação da política:
#
# A função evaluate_policy avalia o desempenho do modelo DQN treinado.

# %%
mean_reward, std_reward = evaluate_policy(
    dqn_model,               # O modelo DQN que foi treinado e será avaliado
    dqn_model.get_env(),     # O ambiente no qual o modelo será avaliado, obtido a partir do modelo treinado
    deterministic=True,      # Se verdadeiro, o agente usará ações determinísticas (sem explorar) durante a avaliação
    n_eval_episodes=20,      # Número de episódios de avaliação para calcular a média e o desvio padrão da recompensa
)

#Resultado: A função evaluate_policy retorna a recompensa média (mean_reward) 
#e o desvio padrão da recompensa (std_reward) após a avaliação do agente em 20 episódios.

print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-200.00 +/- 0.00

# %%
# Optional: Monitor training in tensorboard
# %load_ext tensorboard
# %tensorboard --logdir $tensorboard_log
# Out:
#       <iframe id="tensorboard-frame-dcf4bb99f4bea973" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-dcf4bb99f4bea973");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# # Treinamento do agente DQN por 120.000 passos de tempo,
#
# é carregado na saida as informações de progresso sendo exibidas a cada 10 passos.
# Permite visualizar se o agente está melhorando ao longo do tempo e ajusta o treinamento conforme necessário.

# %%
dqn_model.learn(int(1.2e5), log_interval=10) # int(1.2e5) Converte o valor 1.2e5 (120.000) para um número inteiro
# Out:
# Logging to mountaincar/DQN_3
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 10       |
# |    fps              | 3592     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2000     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.97e-05 |
# |    n_updates        | 496      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.845    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 2784     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4000     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 9.68e-07 |
# |    n_updates        | 1496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.767    |
# | time/               |          |
# |    episodes         | 30       |
# |    fps              | 2566     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6000     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 3.55e-05 |
# |    n_updates        | 2496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.69     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 2412     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 8000     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.05e-05 |
# |    n_updates        | 3496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.612    |
# | time/               |          |
# |    episodes         | 50       |
# |    fps              | 2331     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 10000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 3.02e-06 |
# |    n_updates        | 4496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.535    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 2270     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 12000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 5.74e-06 |
# |    n_updates        | 5496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.457    |
# | time/               |          |
# |    episodes         | 70       |
# |    fps              | 2241     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 14000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.41e-05 |
# |    n_updates        | 6496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.38     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 2225     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 16000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 8.19e-06 |
# |    n_updates        | 7496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.302    |
# | time/               |          |
# |    episodes         | 90       |
# |    fps              | 2210     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 18000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 5.75e-06 |
# |    n_updates        | 8496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.225    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 2175     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 20000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 4.67e-05 |
# |    n_updates        | 9496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.149    |
# | time/               |          |
# |    episodes         | 110      |
# |    fps              | 2152     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 21972    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 4.07e-05 |
# |    n_updates        | 10488    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.0711   |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 2130     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 23972    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 8.85e-06 |
# |    n_updates        | 11488    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 130      |
# |    fps              | 2114     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 25934    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0303   |
# |    n_updates        | 12464    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 2097     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 27807    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000386 |
# |    n_updates        | 13400    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 150      |
# |    fps              | 2090     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 29717    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0246   |
# |    n_updates        | 14360    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 2088     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 31691    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0201   |
# |    n_updates        | 15344    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 170      |
# |    fps              | 2080     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 33642    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0348   |
# |    n_updates        | 16320    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 2072     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 35385    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.00303  |
# |    n_updates        | 17192    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 190      |
# |    fps              | 2063     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 37376    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.00789  |
# |    n_updates        | 18184    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 2041     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 39376    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.00332  |
# |    n_updates        | 19184    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 210      |
# |    fps              | 2033     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 41113    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.023    |
# |    n_updates        | 20056    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 2024     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 42853    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0157   |
# |    n_updates        | 20928    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 230      |
# |    fps              | 2022     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 44725    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0243   |
# |    n_updates        | 21864    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 2016     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 46562    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0275   |
# |    n_updates        | 22784    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 250      |
# |    fps              | 2013     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 48197    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0285   |
# |    n_updates        | 23600    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 2008     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 49971    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0355   |
# |    n_updates        | 24488    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 182      |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 270      |
# |    fps              | 2006     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 51891    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0537   |
# |    n_updates        | 25448    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 182      |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 2003     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 53549    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0391   |
# |    n_updates        | 26272    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 290      |
# |    fps              | 2001     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 54902    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0584   |
# |    n_updates        | 26952    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1998     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 56550    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0364   |
# |    n_updates        | 27776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 310      |
# |    fps              | 1995     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 58352    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0598   |
# |    n_updates        | 28672    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 170      |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1994     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 59867    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.027    |
# |    n_updates        | 29432    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 169      |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 330      |
# |    fps              | 1991     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 61663    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0541   |
# |    n_updates        | 30328    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 168      |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1988     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 63340    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0567   |
# |    n_updates        | 31168    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 165      |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 350      |
# |    fps              | 1984     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 64668    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0695   |
# |    n_updates        | 31832    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 163      |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1983     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 66289    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0828   |
# |    n_updates        | 32648    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 158      |
# |    ep_rew_mean      | -158     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 370      |
# |    fps              | 1981     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 67698    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0458   |
# |    n_updates        | 33352    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | -155     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 1981     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 69027    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0911   |
# |    n_updates        | 34016    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | -155     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 390      |
# |    fps              | 1981     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 70382    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0994   |
# |    n_updates        | 34688    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 152      |
# |    ep_rew_mean      | -152     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 1982     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 71715    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.123    |
# |    n_updates        | 35360    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 147      |
# |    ep_rew_mean      | -147     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 410      |
# |    fps              | 1983     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 73010    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0872   |
# |    n_updates        | 36008    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 145      |
# |    ep_rew_mean      | -145     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 1984     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 74346    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0893   |
# |    n_updates        | 36672    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 140      |
# |    ep_rew_mean      | -140     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 430      |
# |    fps              | 1984     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 75649    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.156    |
# |    n_updates        | 37328    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | -137     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 1985     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 76999    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.132    |
# |    n_updates        | 38000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | -137     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 450      |
# |    fps              | 1985     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 78399    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.148    |
# |    n_updates        | 38696    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 133      |
# |    ep_rew_mean      | -133     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 1985     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 79615    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.13     |
# |    n_updates        | 39304    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 133      |
# |    ep_rew_mean      | -133     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 470      |
# |    fps              | 1986     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 81043    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.245    |
# |    n_updates        | 40024    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 133      |
# |    ep_rew_mean      | -133     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 1984     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 82331    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.123    |
# |    n_updates        | 40664    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | -134     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 490      |
# |    fps              | 1983     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 83733    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.143    |
# |    n_updates        | 41368    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 136      |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 1981     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 85289    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.243    |
# |    n_updates        | 42144    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | -137     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 510      |
# |    fps              | 1981     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 86740    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.265    |
# |    n_updates        | 42872    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | -137     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 1980     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 88028    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.164    |
# |    n_updates        | 43512    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | -137     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 530      |
# |    fps              | 1978     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 89349    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.174    |
# |    n_updates        | 44176    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 135      |
# |    ep_rew_mean      | -135     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 1977     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 90459    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.281    |
# |    n_updates        | 44728    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 132      |
# |    ep_rew_mean      | -132     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 550      |
# |    fps              | 1977     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 91635    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.179    |
# |    n_updates        | 45320    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 133      |
# |    ep_rew_mean      | -133     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 1976     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 92883    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.156    |
# |    n_updates        | 45944    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 130      |
# |    ep_rew_mean      | -130     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 570      |
# |    fps              | 1975     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 94068    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.226    |
# |    n_updates        | 46536    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 130      |
# |    ep_rew_mean      | -130     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 1974     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 95287    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.255    |
# |    n_updates        | 47144    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 128      |
# |    ep_rew_mean      | -128     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 590      |
# |    fps              | 1973     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 96507    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.275    |
# |    n_updates        | 47752    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 126      |
# |    ep_rew_mean      | -126     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 1974     |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 97855    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.348    |
# |    n_updates        | 48424    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 123      |
# |    ep_rew_mean      | -123     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 610      |
# |    fps              | 1974     |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 99056    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.225    |
# |    n_updates        | 49024    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 125      |
# |    ep_rew_mean      | -125     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 1973     |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 100527   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.39     |
# |    n_updates        | 49760    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 126      |
# |    ep_rew_mean      | -126     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 630      |
# |    fps              | 1974     |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 101965   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.258    |
# |    n_updates        | 50480    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 129      |
# |    ep_rew_mean      | -129     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 640      |
# |    fps              | 1974     |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 103333   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.243    |
# |    n_updates        | 51168    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 131      |
# |    ep_rew_mean      | -131     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 650      |
# |    fps              | 1975     |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 104706   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.266    |
# |    n_updates        | 51856    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 131      |
# |    ep_rew_mean      | -131     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 660      |
# |    fps              | 1975     |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 106006   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.277    |
# |    n_updates        | 52504    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 132      |
# |    ep_rew_mean      | -132     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 670      |
# |    fps              | 1976     |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 107294   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.228    |
# |    n_updates        | 53144    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | -134     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 680      |
# |    fps              | 1977     |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 108668   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.163    |
# |    n_updates        | 53832    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 136      |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 690      |
# |    fps              | 1977     |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 110057   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.376    |
# |    n_updates        | 54528    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 135      |
# |    ep_rew_mean      | -135     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 1977     |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 111374   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.284    |
# |    n_updates        | 55184    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 135      |
# |    ep_rew_mean      | -135     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 710      |
# |    fps              | 1977     |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 112552   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.186    |
# |    n_updates        | 55776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 138      |
# |    ep_rew_mean      | -138     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 1979     |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 114352   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.223    |
# |    n_updates        | 56672    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 139      |
# |    ep_rew_mean      | -139     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 730      |
# |    fps              | 1977     |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 115875   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.227    |
# |    n_updates        | 57440    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 139      |
# |    ep_rew_mean      | -139     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 1978     |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 117260   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.224    |
# |    n_updates        | 58128    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 138      |
# |    ep_rew_mean      | -138     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 750      |
# |    fps              | 1978     |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 118477   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.155    |
# |    n_updates        | 58736    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | -137     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 1978     |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 119700   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.225    |
# |    n_updates        | 59352    |
# ----------------------------------

# %%
mean_reward, std_reward = evaluate_policy(dqn_model, dqn_model.get_env(), deterministic=True, n_eval_episodes=20)

print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-98.55 +/- 9.04

# %% [markdown]
# # Gravar o video do Mountain Car

# %%
import base64  # Módulo para codificação e decodificação de dados em base64
from pathlib import Path  # Módulo para manipulação de caminhos de arquivos e diretórios

from IPython import display as ipythondisplay  # Módulo para exibir elementos no Jupyter Notebook

# Função para exibir vídeos no Jupyter Notebook
def show_videos(video_path="", prefix=""):
    """
    Função retirada de https://github.com/eleurent/highway-env

    :param video_path: (str) Caminho para a pasta contendo os vídeos
    :param prefix: (str) Filtra os vídeos, exibindo apenas aqueles que começam com este prefixo
    """
    html = []  # Lista para armazenar o HTML que será gerado para exibir os vídeos
    for mp4 in Path(video_path).glob("{}*.mp4".format(prefix)):  # Itera sobre todos os arquivos .mp4 no diretório especificado que começam com o prefixo
        video_b64 = base64.b64encode(mp4.read_bytes())  # Lê o conteúdo do arquivo de vídeo e o codifica em base64
        html.append(
            """<video alt="{}" autoplay
                    loop controls style="height: 400px;">
                    <source src="data:video/mp4;base64,{}" type="video/mp4" />
                </video>""".format(
                mp4, video_b64.decode("ascii")  # Gera o HTML para exibir o vídeo, usando o conteúdo codificado em base64
            )
        )
    ipythondisplay.display(ipythondisplay.HTML(data="<br>".join(html)))  # Exibe o HTML gerado no Jupyter Notebook

# %%
# Importação da classe VecVideoRecorder e DummyVecEnv do pacote stable_baselines3
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv

# Função para gravar um vídeo do ambiente enquanto o agente treinado interage com ele
def record_video(
    env_id,                     # ID do ambiente (string) que será gravado
    model,                      # Modelo de RL treinado
    video_length=500,           # Duração do vídeo em número de passos no ambiente
    prefix="",                  # Prefixo para o nome do arquivo de vídeo
    video_folder="videos/",     # Pasta onde os vídeos serão armazenados
):

    # Cria um ambiente de avaliação usando DummyVecEnv, necessário para usar VecVideoRecorder
    eval_env = DummyVecEnv([lambda: gym.make(env_id, render_mode="rgb_array")])
    
    # Inicia o gravador de vídeo no passo 0 e grava 500 passos
    eval_env = VecVideoRecorder(
        eval_env,
        video_folder=video_folder,                    # Pasta onde os vídeos serão armazenados
        record_video_trigger=lambda step: step == 0,  # Grava o vídeo a partir do passo 0
        video_length=video_length,                    # Duração do vídeo em passos
        name_prefix=prefix,                           # Prefixo para o nome do arquivo de vídeo
    )

    # Reinicia o ambiente e obtém a observação inicial
    obs = eval_env.reset()
    for _ in range(video_length):
        # Prediz a próxima ação usando o modelo treinado, sem ser determinístico
        action, _ = model.predict(obs, deterministic=False)
        # Toma a ação no ambiente
        obs, _, _, _ = eval_env.step(action)

    # Fecha o gravador de vídeo
    eval_env.close()

# %% [markdown]
# # Visualizando o agente treinado

# %%
# !pip install ffmpeg #Instala o pacote ffmpeg, necessário para manipulação de vídeo
# Out:
# Requirement already satisfied: ffmpeg in /Users/bruna/opt/anaconda3/lib/python3.9/site-packages (1.4)

# %%
# Grava um vídeo da interação do agente DQN com o ambiente "MountainCar-v0"
record_video("MountainCar-v0", dqn_model, video_length=500, prefix="dqn-mountaincar")

# %%
show_videos("videos", prefix="dqn") # carregando o video final
# Out:
# <video alt="videos/dqn-mountaincar-step-0-to-step-500.mp4" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>

# %% [markdown]
# # Biblioteca para baixar o notebook como Latex

# %%
# !pip install pandoc
# Out:
# Collecting pandoc
#   Downloading pandoc-2.3.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Collecting plumbum
#   Downloading plumbum-1.8.3-py3-none-any.whl (127 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.6/127.6 kB 3.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: ply in /Users/bruna/opt/anaconda3/lib/python3.9/site-packages (from pandoc) (3.11)
# Building wheels for collected packages: pandoc
#   Building wheel for pandoc (setup.py) ... done
#   Created wheel for pandoc: filename=pandoc-2.3-py3-none-any.whl size=33262 sha256=d3c0a22aa845af0f3d162b3765e14268b3f819dc082ee29dba98b82c749bb88d
#   Stored in directory: /Users/bruna/Library/Caches/pip/wheels/69/e6/a1/1daa96d919c9e09a71473649b717b8da286f3f8d7719d1cfc5
# Successfully built pandoc
# Installing collected packages: plumbum, pandoc
# Successfully installed pandoc-2.3 plumbum-1.8.3
